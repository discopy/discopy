# %%
from discopy import Ty, Word

s, n = Ty('s'), Ty('n')
Alice, loves, Bob = Word('Alice', n), Word('loves', n.r @ s @ n.l), Word('Bob', n)

print("Vocabulary:\n{}".format('\n'.join(map(repr, [Alice, loves, Bob]))))
# Out:
# Vocabulary:
# Word('Alice', Ty('n'))
# Word('loves', Ty(Ob('n', z=1), 's', Ob('n', z=-1)))
# Word('Bob', Ty('n'))

# %%
from discopy import Diagram, Id, Cup
from discopy.grammar import draw

grammar = Cup(n, n.r) @ Id(s) @ Cup(n.l, n)
parsing = {"{} {} {}.".format(subj, verb, obj): subj @ verb @ obj >> grammar
            for subj in [Alice, Bob] for verb in [loves] for obj in [Alice, Bob]}

diagram = parsing['Alice loves Bob.']
print("Diagram for 'Alice loves Bob':")
draw(diagram, draw_type_labels=True)
# Out:
# Diagram for 'Alice loves Bob':

# %%
sentences = list(parsing.keys())
print("Grammatical sentences:\n{}".format('\n'.join(sentences)))
# Out:
# Grammatical sentences:
# Alice loves Alice.
# Alice loves Bob.
# Bob loves Alice.
# Bob loves Bob.

# %%
from discopy.quantum import Ket, H, Rx, CX, sqrt

def verb_ansatz(phase):
    return Ket(0, 0) >> H @ sqrt(2) @ Rx(phase) >> CX

print(verb_ansatz(0).eval())
# Out:
# Tensor(dom=Dim(1), cod=Dim(2, 2), array=[1.+0.j, 0.+0.j, 0.+0.j, 1.+0.j])

# %%
(verb_ansatz(0) >> verb_ansatz(0.5).dagger()).measure()
# Out:
# array([1.49975978e-32])

# %%
.25 * (verb_ansatz(0) >> verb_ansatz(0).dagger()).measure()
# Out:
# array([1.])

# %%
from discopy import CircuitFunctor, qubit

ob = {s: 0, n: 1}
ar = lambda params: {
    Alice: Ket(0), Bob: Ket(1),
    loves: verb_ansatz(params['loves'])}

F = lambda params: CircuitFunctor(ob, ar(params))

params0 = {'loves': 0.5}

print("Circuit for 'Alice loves Bob':")
F(params0)(parsing['Alice loves Bob.']).draw(
    aspect='auto', draw_type_labels=False, figsize=(5, 5))
F(params0)(parsing['Alice loves Bob.'])
# Out:
# Circuit for 'Alice loves Bob':
# Circuit(dom=qubit ** 0, cod=qubit ** 0, boxes=[Ket(0), Ket(0, 0), H, sqrt(2), Rx(0.5), CX, Ket(1), CX, H, sqrt(2), Bra(0, 0), CX, H, sqrt(2), Bra(0, 0)], offsets=[0, 1, 1, 2, 2, 1, 3, 0, 0, 1, 0, 0, 0, 1, 0])

# %%
print("Amplitude for 'Alice loves Bob':")
print(F(params0)(parsing['Alice loves Bob.']).eval())
# Out:
# Amplitude for 'Alice loves Bob':
# Tensor(dom=Dim(1), cod=Dim(1), array=[0.-1.j])

# %%
evaluate = lambda F, sentence: F(parsing[sentence]).measure()

print("Does Alice love Bob?\n{}".format(
    "Yes" if evaluate(F(params0), 'Alice loves Bob.') else "No"))
# Out:
# Does Alice love Bob?
# Yes

# %%
corpus = {sentence: evaluate(F(params0), sentence) for sentence in sentences}

epsilon = 1e-2

print("True sentences:\n{}\n".format('\n'.join(sentence
    for sentence, probability in corpus.items() if probability > 1 - epsilon)))
print("False sentences:\n{}".format('\n'.join(sentence
    for sentence, probability in corpus.items() if probability < epsilon)))
# Out:
# True sentences:
# Alice loves Bob.
# Bob loves Alice.
#
# False sentences:
# Alice loves Alice.
# Bob loves Bob.

# %%
import jax.numpy as np
from jax import grad

def mean_squared(y_true, y_pred):
    return np.mean((np.array(y_true) - np.array(y_pred)) ** 2)

f = lambda phase: mean_squared(*zip(*[
    (evaluate(F(params0), sentence), evaluate(F({'loves': phase}), sentence))
     for sentence in sentences]))

grad(f)(0.75)
# Out:
# /Users/alexis.toumi/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/lib/xla_bridge.py:130: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-11-dcaae69a79f3> in <module>
#      10
# ---> 11 grad(f)(0.75)
#
# <ipython-input-11-dcaae69a79f3> in <lambda>(phase)
#       6
# ----> 7 f = lambda phase: mean_squared(*zip(*[
#       8     (evaluate(F(params0), sentence), evaluate(F({'loves': phase}), sentence))
#
# <ipython-input-11-dcaae69a79f3> in <listcomp>(.0)
#       7 f = lambda phase: mean_squared(*zip(*[
# ----> 8     (evaluate(F(params0), sentence), evaluate(F({'loves': phase}), sentence))
#       9      for sentence in sentences]))
#
# <ipython-input-9-9f5f5a21c44b> in <lambda>(F, sentence)
# ----> 1 evaluate = lambda F, sentence: F(parsing[sentence]).measure()
#       2
#       3 print("Does Alice love Bob?\n{}".format(
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/quantum/circuit.py in measure(self, mixed)
#     303             return self.init_and_discard().eval(mixed=True).array.real
# --> 304         state = (Ket(*(len(self.dom) * [0])) >> self).eval()
#     305         effects = [Bra(*index2bitstring(j, len(self.cod))).eval()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/quantum/circuit.py in eval(self, backend, mixed, *others, **params)
#     214                 else tensor.Functor(lambda x: 2, lambda f: f.array)
# --> 215             result = functor(circuit)
#     216             for process in post_processes.boxes:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/tensor.py in __call__(self, diagram)
#     315             target = list(range(dim(box.dom)))
# --> 316             array = np.tensordot(array, self(box).array, (source, target))
#     317             source = range(len(array.shape) - dim(box.cod), len(array.shape))
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/tensor.py in __call__(self, diagram)
#     292             return Tensor(self(diagram.dom), self(diagram.cod),
# --> 293                           self.ar[diagram])
#     294         if not isinstance(diagram, monoidal.Diagram):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/cat.py in __getitem__(self, box)
#     836     def __getitem__(self, box):
# --> 837         return self._func(box)
#     838
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/quantum/circuit.py in <lambda>(f)
#     213             functor = cqmap.Functor() if mixed or self.is_mixed\
# --> 214                 else tensor.Functor(lambda x: 2, lambda f: f.array)
#     215             result = functor(circuit)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/quantum/gates.py in array(self)
#     278         half_theta = np.pi * self.phase
# --> 279         sin, cos = np.sin(half_theta), np.cos(half_theta)
#     280         return np.array([[cos, -1j * sin], [-1j * sin, cos]])
#
# FilteredStackTrace: Exception: The numpy.ndarray conversion method __array__() was called on the JAX Tracer object Traced<ConcreteArray(2.3561945)>with<JVPTrace(level=2/0)>
#   with primal = DeviceArray(2.3561945, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=1/0)>.
#
# This error can occur when a JAX Tracer object is passed to a raw numpy function, or a method on a numpy.ndarray object. You might want to check that you are using `jnp` together with `import jax.numpy as jnp` rather than using `np` via `import numpy as np`. If this error arises on a line that involves array indexing, like `x[idx]`, it may be that the array being indexed `x` is a raw numpy.ndarray while the indices `idx` are a JAX Tracer instance; in that case, you can instead write `jax.device_put(x)[idx]`.
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-dcaae69a79f3> in <module>
#       9      for sentence in sentences]))
#      10
# ---> 11 grad(f)(0.75)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     135   def reraise_with_filtered_traceback(*args, **kwargs):
#     136     try:
# --> 137       return fun(*args, **kwargs)
#     138     except Exception as e:
#     139       if not is_under_reraiser(e):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/api.py in grad_f(*args, **kwargs)
#     742   @api_boundary
#     743   def grad_f(*args, **kwargs):
# --> 744     _, g = value_and_grad_f(*args, **kwargs)
#     745     return g
#     746
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     135   def reraise_with_filtered_traceback(*args, **kwargs):
#     136     try:
# --> 137       return fun(*args, **kwargs)
#     138     except Exception as e:
#     139       if not is_under_reraiser(e):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     802     tree_map(partial(_check_input_dtype_grad, holomorphic), dyn_args)
#     803     if not has_aux:
# --> 804       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     805     else:
#     806       ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/api.py in _vjp(fun, has_aux, *primals)
#    1846   if not has_aux:
#    1847     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1848     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1849     out_tree = out_tree()
#    1850   else:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     108 def vjp(traceable, primals, has_aux=False):
#     109   if not has_aux:
# --> 110     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     111   else:
#     112     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      95   _, in_tree = tree_flatten(((primals, primals), {}))
#      96   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# ---> 97   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#      98   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#      99   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate)
#     402   with core.new_main(JaxprTrace) as main:
#     403     fun = trace_to_subjaxpr(fun, main, instantiate)
# --> 404     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     405     assert not env
#     406     del main
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     149
#     150     try:
# --> 151       ans = self.f(*args, **dict(self.params, **kwargs))
#     152     except:
#     153       # Some transformations yield from inside context managers, so we have to
#
# <ipython-input-11-dcaae69a79f3> in <lambda>(phase)
#       5     return np.mean((np.array(y_true) - np.array(y_pred)) ** 2)
#       6
# ----> 7 f = lambda phase: mean_squared(*zip(*[
#       8     (evaluate(F(params0), sentence), evaluate(F({'loves': phase}), sentence))
#       9      for sentence in sentences]))
#
# <ipython-input-11-dcaae69a79f3> in <listcomp>(.0)
#       6
#       7 f = lambda phase: mean_squared(*zip(*[
# ----> 8     (evaluate(F(params0), sentence), evaluate(F({'loves': phase}), sentence))
#       9      for sentence in sentences]))
#      10
#
# <ipython-input-9-9f5f5a21c44b> in <lambda>(F, sentence)
# ----> 1 evaluate = lambda F, sentence: F(parsing[sentence]).measure()
#       2
#       3 print("Does Alice love Bob?\n{}".format(
#       4     "Yes" if evaluate(F(params0), 'Alice loves Bob.') else "No"))
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/quantum/circuit.py in measure(self, mixed)
#     302         if mixed or self.is_mixed:
#     303             return self.init_and_discard().eval(mixed=True).array.real
# --> 304         state = (Ket(*(len(self.dom) * [0])) >> self).eval()
#     305         effects = [Bra(*index2bitstring(j, len(self.cod))).eval()
#     306                    for j in range(2 ** len(self.cod))]
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/quantum/circuit.py in eval(self, backend, mixed, *others, **params)
#     213             functor = cqmap.Functor() if mixed or self.is_mixed\
#     214                 else tensor.Functor(lambda x: 2, lambda f: f.array)
# --> 215             result = functor(circuit)
#     216             for process in post_processes.boxes:
#     217                 result = process(result)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/tensor.py in __call__(self, diagram)
#     314                                 dim(diagram.dom) + left + dim(box.dom)))
#     315             target = list(range(dim(box.dom)))
# --> 316             array = np.tensordot(array, self(box).array, (source, target))
#     317             source = range(len(array.shape) - dim(box.cod), len(array.shape))
#     318             target = range(dim(diagram.dom) + left,
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/tensor.py in __call__(self, diagram)
#     291                 return self(diagram.dagger()).dagger()
#     292             return Tensor(self(diagram.dom), self(diagram.cod),
# --> 293                           self.ar[diagram])
#     294         if not isinstance(diagram, monoidal.Diagram):
#     295             raise TypeError(messages.type_err(monoidal.Diagram, diagram))
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/cat.py in __getitem__(self, box)
#     835
#     836     def __getitem__(self, box):
# --> 837         return self._func(box)
#     838
#     839     def __repr__(self):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/quantum/circuit.py in <lambda>(f)
#     212             circuit = self[:-len(post_processes) or len(self)]
#     213             functor = cqmap.Functor() if mixed or self.is_mixed\
# --> 214                 else tensor.Functor(lambda x: 2, lambda f: f.array)
#     215             result = functor(circuit)
#     216             for process in post_processes.boxes:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/discopy/quantum/gates.py in array(self)
#     277     def array(self):
#     278         half_theta = np.pi * self.phase
# --> 279         sin, cos = np.sin(half_theta), np.cos(half_theta)
#     280         return np.array([[cos, -1j * sin], [-1j * sin, cos]])
#     281
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/jax/core.py in __array__(self, *args, **kw)
#     442            "JAX Tracer instance; in that case, you can instead write "
#     443            "`jax.device_put(x)[idx]`.")
# --> 444     raise Exception(msg)
#     445
#     446   def __init__(self, trace: Trace):
#
# Exception: The numpy.ndarray conversion method __array__() was called on the JAX Tracer object Traced<ConcreteArray(2.3561945)>with<JVPTrace(level=2/0)>
#   with primal = DeviceArray(2.3561945, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=1/0)>.
#
# This error can occur when a JAX Tracer object is passed to a raw numpy function, or a method on a numpy.ndarray object. You might want to check that you are using `jnp` together with `import jax.numpy as jnp` rather than using `np` via `import numpy as np`. If this error arises on a line that involves array indexing, like `x[idx]`, it may be that the array being indexed `x` is a raw numpy.ndarray while the indices `idx` are a JAX Tracer instance; in that case, you can instead write `jax.device_put(x)[idx]`.

# %%
from jax import vmap

x = np.arange(0.0, 1.0, 0.01)
y = vmap(f)(x)
dy = vmap(grad(f))(x)

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (12, 5)

plt.subplot(2, 1, 1)
plt.plot(x, y)
plt.title("functorial landscape for 'loves'")
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(x, dy)
plt.xlabel('phase')
plt.ylabel('grad')
plt.show()

# %%
from sklearn.model_selection import train_test_split

sentence_train, sentence_test = train_test_split(sentences, test_size=0.25, random_state=42)

print("Training set:\n{}\n".format('\n'.join(sentence_train)))
print("Testing set:\n{}".format('\n'.join(map(
    lambda x: 'Does ' + x.replace('loves', 'love').replace('.', '?'), sentence_test))))

# %%
from jax import jit
from time import time

loss = {sentence: lambda params: mean_squared(corpus[sentence], evaluate(F(params), sentence))
                 for sentence in sentences}

@jit
def testing_loss(params):
    return np.mean(np.array([loss[sentence](params) for sentence in sentence_test]))

start = time()
print("{1:.3f} seconds to compile the testing loss of params0 ({0})".format(
    testing_loss(params0), time() - start))

step_size = 1e-2

@jit
def update(params):
    for sentence in sentence_train:
        params = {word: phase - step_size * grad(loss[sentence])(params)[word]
                  for word, phase in params.items()}
    return params

start = time()
print("{1:.3f} seconds to compile the update function just in time:\n{0}".format(
    update(params0), time() - start))

# %%
from random import random, seed; seed(420)

print("Random parameter initialisation...")

params = {'loves': random()}
print("Initial parameters: {}".format(params))

print("Initial testing loss: {:.5f}\n".format(testing_loss(params)))

epochs, iterations = 7, 10

for epoch in range(epochs):
    start = time()
    for i in range(iterations):
        params = update(params)

    print("Epoch {} ({:.3f} milliseconds)".format(epoch, 1e3 * (time() - start)))
    print("Testing loss: {:.5f}".format(testing_loss(params)))
    print("params['loves'] = {:.3f}\n".format(params['loves']))

# %%
print("Does Alice love Bob?")
print("Yes" if evaluate(F(params), 'Alice loves Bob.') > 1 - epsilon else "No")
